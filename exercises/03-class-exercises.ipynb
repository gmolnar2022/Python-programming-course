# %% [markdown]
# # Class Exercises 3
#
# **Conditional Statements in Python**
#
# Complete the exercises in order. Write your solution in the code cell below each task.
#
# [Open in Google Colab](https://colab.research.google.com/github/gmolnar2022/Python-programming-course/blob/main/exercises/03-class-exercises.ipynb)
#
# > **Before you start**
# >
# > If Colab displays a security warning, select **Run anyway**.
# > Then select **File → Save a copy in Drive** and work in your own copy.
# > Run the **Setup** cell below once before starting.

# %% [markdown]
# ## Setup
#
# Run this cell once at the beginning of the session.

# %%
# Setup – run this cell first
# !wget -q https://raw.githubusercontent.com/gmolnar2022/Python-programming-course/main/checker/checker.py -O checker.py
import importlib, checker
importlib.reload(checker)
from checker import check_button
print("✓ Exercise checker is ready.")

# %% [markdown]
# ## Exercise 1 — 10 minutes
#
# Write a program that asks the user for a **non-zero integer** and checks whether it is **positive or negative**.

# %%
# Write your solution here

# %%
check_button("week03_ex01")

# %% [markdown]
# ## Exercise 2 — 10 minutes
#
# Write a program that reads **two different floating-point numbers** and displays the larger one.
#
# Example output:
#
# ```text
# The given numbers are 23.4 and 11.2, the larger one is 23.4
# ```

# %%
# Write your solution here

# %%
check_button("week03_ex02")

# %% [markdown]
# ## Exercise 3 — 10 minutes
#
# Write a program that solves a **quadratic equation** $ax^2 + bx + c = 0$.
#
# - Read `a`, `b`, and `c` as floating-point numbers.
# - Calculate the discriminant: `d = b**2 - 4*a*c`.
# - If there is **no real solution**, display an error message.
# - Otherwise, calculate and display the two real solutions.
# - Follow the logic of the flowchart in the original exercise sheet.

# %%
# Write your solution here

# %%
check_button("week03_ex03")

# %% [markdown]
# ## Exercise 4 — 10 minutes
#
# Write a program that reads **three integers** and finds the largest one.
#
# Example output:
#
# ```text
# The given numbers are 14, 22, 11, the largest one is 22
# ```
#
# Follow the logic of the flowchart in the original exercise sheet.

# %%
# Write your solution here

# %%
check_button("week03_ex04")

# %% [markdown]
# ## Exercise 5 — 10 minutes
#
# At the end of the semester, a student receives marks in three subjects: **Physics, Mathematics, and Chemistry**. Each mark is between `0` and `100`.
#
# Write a program that:
#
# 1. reads the student's **name** and the three marks,
# 2. calculates the **total marks** and the **percentage**,
# 3. checks whether the percentage is at least **50%**,
# 4. also checks that **none of the three marks is below 40**,
# 5. displays the student's name and the result: **Passed** or **Failed**.

# %%
# Write your solution here

# %%
check_button("week03_ex05")

# %% [markdown]
# ## Exercise 6 — 10 minutes
#
# Write a program that reads a temperature in degrees Celsius and displays:
#
# - **Hot** if the temperature is greater than `30`,
# - **Normal** if the temperature is between `10` and `30`,
# - **Cold** if the temperature is less than `10` but greater than or equal to `0`,
# - **Freezing** if the temperature is below `0`.

# %%
# Write your solution here

# %%
check_button("week03_ex06")
