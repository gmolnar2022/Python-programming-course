# %% [markdown]
# # Class Exercises 2
#
# **Introduction to Data Science and Programming**
# **Week 2 – Working with Simple Data Types**
#
# [Open in Google Colab](https://colab.research.google.com/github/gmolnar2022/Python-programming-course/blob/main/exercises/02-class-exercises.ipynb)
#
# > ⚠️ **Before you start**
# >
# > After opening the notebook in Google Colab, save your own copy:
# > **File → Save a copy in Drive**
# >
# > Work in your own copy.
# >
# > Run the **Setup** cell below once before starting the exercises.
#
# Complete the exercises in order. Write your solution in the code cell below each task.

# %% [markdown]
# ## Setup
#
# Run this cell once at the beginning of the session.

# %%
# Setup – run this cell first

# !wget -q https://raw.githubusercontent.com/gmolnar2022/Python-programming-course/main/checker/checker.py -O checker.py

import importlib
import checker
importlib.reload(checker)

from checker import check_button

print("✓ Exercise checker is ready.")

# %% [markdown]
# ## Exercise 1 — 10 minutes
#
# Write a program that calculates and displays on the screen:
#
# - the **sum, difference, product, and quotient** of two integers,
# - the **remainder** when the first number is divided by the second,
# - the first number **increased by 1** and the second number **decreased by 1**.
#
# Ask the user to enter the two integers.

# %%
# Write your solution here

# %%
check_button("week02_ex01")

# %% [markdown]
# ## Exercise 2 — 10 minutes
#
# Write a program that solves a **linear equation**.
#
# - The coefficients of the equation should be asked from the user.
#
# You may assume that the coefficient of `x` is not zero.

# %%
# Write your solution here

# %%
check_button("week02_ex02")

# %% [markdown]
# ## Exercise 3 — 10 minutes
#
# Write a program that calculates and displays the **volume** and **surface area** of a cuboid.
#
# - The edges should be floating-point numbers entered by the user.

# %%
# Write your solution here

# %%
check_button("week02_ex03")

# %% [markdown]
# ## Exercise 4 — 10 minutes
#
# You are interested in buying a new laptop with a given **net price** and **tax rate**. Calculate and display the **gross price** of the laptop.
#
# - Ask the user for the necessary values.
# - Enter the tax rate as a percentage (for example, `27` for 27%).

# %%
# Write your solution here

# %%
check_button("week02_ex04")

# %% [markdown]
# ## Exercise 5 — 10 minutes
#
# At the end of the semester, a student receives grades from **5 subjects**. Write a program that:
#
# - reads the values of grades one by one,
# - calculates the **average grade**.

# %%
# Write your solution here

# %%
check_button("week02_ex05")

# %% [markdown]
# ## Exercise 6 — 10 minutes
#
# We put a given amount of money in the bank at a given **annual interest rate**. How much money will we have in **5 years**?
#
# - Read the amount and the interest rate.
# - Calculate the ending amount.
# - Enter the interest rate as a percentage (for example, `5` for 5%).

# %%
# Write your solution here

# %%
check_button("week02_ex06")

# %% [markdown]
# ## Homework
#
# Write a program that converts an amount given in **US dollars** into **euros** and **Hungarian forints**.
#
# Use these exchange rates:
#
# - `1 USD = 0.93 EUR`
# - `1 USD = 354.15 HUF`

# %%
# Write your solution here

# %%
check_button("week02_ex07")
